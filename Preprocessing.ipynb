# %%
#Import file & resources

import pandas as pd
import numpy as np

# %%
#Read file into df

df = pd.read_csv("Android apps.csv", low_memory=False)

#df

# %%
#Filter out non-game app data
print(f"size before filter: {len(df)}")
df = df.loc[df['game']==1]
print(f"size after filtering by game: {len(df)}")

#Filter out invalid data
df = df.loc[(df['numberreviews'] != 'error during scraping') & (df['numberreviews'] != 'rating disabled')]
print(f"size after filtering out invalid numberreviews values: {len(df)}")
#df
# Out:
# size before filter: 50217
# size after filtering by game: 11109
# size after filtering out invalid numberreviews values: 10621

# %%
#Keep features/columns

columns_keep = 'appname	fancyname	company	purchases	ads	sharesinfo	shareslocation	unrestrictedinternet	usersinteract	game	age_rating	Parentalguidance	Downloads	categorygame	low_price_item	top_price_item	price	paidapp	rating	numberreviews'.split('\t')

df = df[columns_keep]
#df

# %%
# Drop nan of numberreviews

df_notna = df[df['numberreviews'].notna()]
#df_notna

# %%
# Create function to replace specific string characters in numberreviews for conversion purposes

def CleanNumberString(numberString):
    #print(f"number to cleanse: {numberString}")
    cleanedString = numberString.replace(",","").replace("","").replace("k","").replace("+","").replace("m","")
    #print (f"cleaned string: {cleanedString}")
    return cleanedString

# %%
# Create function chained with CleanNumberString to convert numerical objects to numerical values

def CleanNumber(numberString):
    multiplier = 1

    if('k' in numberString):
        multiplier = 1000
    elif('m' in numberString):
        multiplier = 1000000
        
    cleanedString = float(CleanNumberString(numberString)) * multiplier    
    
    return cleanedString

# %%
# Create clean numerical values in string format in numberreviews column

df_notna["cleaned_numberReviews"] = df_notna["numberreviews"]
#df_notna
df_notna['cleaned_numberReviews'] = df_notna.apply(lambda row: CleanNumber(row['cleaned_numberReviews']), axis=1)
# Out:
# C:\Users\artem\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\artem\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# Double check whether function is working as planned

df_notna[df_notna['numberreviews'].str.contains("m")]
# Out:
#                                    appname  \
# 41728  com.gameloft.android.ANMP.GloftSIHM
# 41771  com.gameloft.android.ANMP.GloftUOHM
# 42130                   com.disney.WMWLite
# 42131                     com.pikpok.turbo
# 42311                 com.umonistudio.tile
# 42594             com.nordcurrent.Games101
# 42795              com.izmo.onlinekafatopu
# 44077                      mobi.MultiCraft
# 44209     com.activision.callofduty.heroes
# 47013       com.telltalegames.minecraft100
#
#                                                fancyname  \
# 41728                        MARVEL Spider-Man Unlimited
# 41771                                    UNO ? & Friends
# 42130                             Where's My Water? Free
# 42131                                         Turbo FAST
# 42311                           Don't Tap The White Tile
# 42594                                     101-in-1 Games
# 42795                                 Online Head Ball 3
# 44077  <U+25BA> MultiCraft <U+2015> Free Miner! <U+00...
# 44209                              Call of Duty?: Heroes
# 47013                             Minecraft: Story Mode
#
#                            company  purchases  ads  sharesinfo  \
# 41728                     gameloft        NaN  NaN         NaN
# 41771                     gameloft        NaN  NaN         NaN
# 42130                       disney        NaN  NaN         NaN
# 42131                       pikpok        NaN  NaN         NaN
# 42311                cheetah games        NaN  NaN         NaN
# 42594                  nordcurrent        NaN  NaN         NaN
# 42795                masomo gaming        NaN  NaN         NaN
# 44077          multicraft official        NaN  NaN         NaN
# 44209  activision publishing, inc.        NaN  NaN         NaN
# 47013               telltale games        NaN  NaN         NaN
#
#        shareslocation  unrestrictedinternet  usersinteract  game  ...  \
# 41728             NaN                   NaN            NaN     1  ...
# 41771             NaN                   NaN            NaN     1  ...
# 42130             NaN                   NaN            NaN     1  ...
# 42131             NaN                   NaN            NaN     1  ...
# 42311             NaN                   NaN            NaN     1  ...
# 42594             NaN                   NaN            NaN     1  ...
# 42795             NaN                   NaN            NaN     1  ...
# 44077             NaN                   NaN            NaN     1  ...
# 44209             NaN                   NaN            NaN     1  ...
# 47013             NaN                   NaN            NaN     1  ...
#
#       Parentalguidance  Downloads  categorygame low_price_item top_price_item  \
# 41728              0.0        NaN        action            NaN            NaN
# 41771              0.0        NaN          card            NaN            NaN
# 42130              0.0        NaN        puzzle            NaN            NaN
# 42131              0.0        NaN        racing            NaN            NaN
# 42311              0.0        NaN        arcade            NaN            NaN
# 42594              0.0        NaN        arcade            NaN            NaN
# 42795              0.0        NaN        sports            NaN            NaN
# 44077              0.0        NaN     adventure            NaN            NaN
# 44209              0.0        NaN        action            NaN            NaN
# 47013              0.0        NaN     adventure            NaN            NaN
#
#       price paidapp  rating numberreviews cleaned_numberReviews
# 41728  free     0.0     4.2         2.4m+             2400000.0
# 41771  free     0.0     4.1        1.69m+             1690000.0
# 42130  free     0.0     4.3         1.4m+             1400000.0
# 42131  free     0.0     4.3        1.34m+             1340000.0
# 42311  free     0.0     4.3        2.96m+             2960000.0
# 42594  free     0.0     4.4         1.1m+             1100000.0
# 42795  free     0.0     4.4        1.13m+             1130000.0
# 44077  free     0.0     4.3        1.32m+             1320000.0
# 44209  free     0.0     4.4        1.61m+             1610000.0
# 47013  free     0.0     4.3        1.11m+             1110000.0
#
# [10 rows x 21 columns]

# %%
# Attempt to cast cleansed column as int - should throw errors if cleansing is incomplete
df_notna.cleaned_numberReviews = df_notna.cleaned_numberReviews.astype(np.int64)
df_notna
# Out:
# C:\Users\artem\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                    appname  \
# 228                     com.gamebasics.osm
# 235          com.fgol.HungrySharkEvolution
# 246                    com.zynga.livepoker
# 247     ee.dustland.android.dustlandsudoku
# 254             com.miniclip.eightballpool
# ...                                    ...
# 50172                com.ea.tetrisfree_row
# 50188          com.worms2armageddon.apptnb
# 50190       com.nianticlabs.hpwu.prod.ares
# 50192  com.daysofwonder.smallworld2_humble
# 50197       com.melesta.toydefense2flexion
#
#                                                fancyname  \
# 228                          Online Soccer Manager (OSM)
# 235                               Hungry Shark Evolution
# 246    Zynga Poker ? Free Texas Holdem Online Card Games
# 247                               Sudoku - The Clean One
# 254                                          8 Ball Pool
# ...                                                  ...
# 50172                                       TETRIS Blitz
# 50188                                Worms 2: Armageddon
# 50190                       Harry Potter:  Wizards Unite
# 50192                                     Small World 2
# 50197                          Toy Defense - TD Strategy
#
#                        company  purchases  ads  sharesinfo  shareslocation  \
# 228              gamebasics bv        1.0  1.0         0.0             0.0
# 235      ubisoft entertainment        1.0  1.0         0.0             0.0
# 246                      zynga        1.0  1.0         1.0             0.0
# 247            dustland design        1.0  1.0         0.0             0.0
# 254               miniclip.com        1.0  1.0         0.0             0.0
# ...                        ...        ...  ...         ...             ...
# 50172          electronic arts        1.0  0.0         0.0             0.0
# 50188  team 17 digital limited        0.0  0.0         0.0             0.0
# 50190            niantic, inc.        1.0  0.0         0.0             0.0
# 50192                  no info        NaN  NaN         NaN             NaN
# 50197            melsoft games        1.0  1.0         0.0             0.0
#
#        unrestrictedinternet  usersinteract  game  ... Parentalguidance  \
# 228                     0.0            1.0     1  ...              0.0
# 235                     0.0            0.0     1  ...              0.0
# 246                     0.0            1.0     1  ...              0.0
# 247                     0.0            0.0     1  ...              0.0
# 254                     0.0            0.0     1  ...              0.0
# ...                     ...            ...   ...  ...              ...
# 50172                   0.0            0.0     1  ...              0.0
# 50188                   0.0            0.0     1  ...              0.0
# 50190                   0.0            0.0     1  ...              0.0
# 50192                   NaN            NaN     1  ...              0.0
# 50197                   0.0            0.0     1  ...              0.0
#
#          Downloads  categorygame low_price_item top_price_item price paidapp  \
# 228     10000000.0        sports           0.59         109.99  free     0.0
# 235    100000000.0        arcade           2.29         109.99  free     0.0
# 246     50000000.0        casino           0.59         350.00  free     0.0
# 247      1000000.0        puzzle           1.89           2.99  free     0.0
# 254    500000000.0        sports           0.79          99.99  free     0.0
# ...            ...           ...            ...            ...   ...     ...
# 50172   10000000.0        puzzle           1.09         109.99  free     0.0
# 50188    1000000.0      strategy            NaN            NaN  4.49     1.0
# 50190    5000000.0     adventure           1.09         109.99  free     0.0
# 50192          NaN         board            NaN            NaN  free     0.0
# 50197    1000000.0      strategy           0.99         109.99  free     0.0
#
#        rating numberreviews cleaned_numberReviews
# 228       4.5     1,656,120               1656120
# 235       4.5     6,495,234               6495234
# 246       4.5     2,315,552               2315552
# 247       4.6         6,639                  6639
# 254       4.5    17,053,699              17053699
# ...       ...           ...                   ...
# 50172     4.2       250,381                250381
# 50188     3.9        61,603                 61603
# 50190     3.9       268,773                268773
# 50192     4.3        5.66k+                  5660
# 50197     4.5        78,832                 78832
#
# [10525 rows x 21 columns]

# %%
# Get distribution of number of reviews values

df_notna['cleaned_numberReviews'].describe()
# Out:
# count    1.052500e+04
# mean     1.564649e+05
# std      1.021994e+06
# min      1.000000e+00
# 25%      1.010000e+03
# 50%      8.789000e+03
# 75%      5.307300e+04
# max      5.020212e+07
# Name: cleaned_numberReviews, dtype: float64

# %%
# Check lengths before/after removal of first quartile figures

print(len(df_notna))

df_notna = df_notna.loc[df_notna['cleaned_numberReviews'] >= 1000]
print(len(df_notna))
# Out:
# 10525
# 7905

# %%
# Double check ratings data for any quirks

df_notna.rating.unique()
# Out:
# array(['4.5', '4.6', '3.4', '4.3', '4.2', '4.4', '3.8', '4.0', '4.7',
#        '3.2', '3.5', '4.1', '3.7', '3.9', '3.6', '3.3', '4.8', '3.1',
#        '3.0', '2.5', '2.9', '2.7', '2.6', '2.8', '2.3', '2.4', '2.2',
#        '4.9', '1.7', '2.0', '1.9', '1.5', '2.1', '1.8', '1.3', '1.6'],
#       dtype=object)

# %%
# Cast ratings as float type

df_notna.rating = df_notna.rating.astype(np.float)
# Out:
# C:\Users\artem\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Double check latest dtypes on df

df_notna.dtypes
# Out:
# fancyname                 object
# company                   object
# purchases                float64
# ads                      float64
# sharesinfo               float64
# shareslocation           float64
# unrestrictedinternet     float64
# usersinteract            float64
# game                       int64
# age_rating                object
# Parentalguidance         float64
# Downloads                float64
# categorygame              object
# low_price_item            object
# top_price_item            object
# price                     object
# paidapp                  float64
# rating                   float64
# numberreviews             object
# cleaned_numberReviews      int64
# dtype: object

# %%
# Export clean csv for machine learning purposes

#df_notna.to_csv(".\cleaned.csv", index=False)

# %%
# Load Google play data
df_gp = pd.read_csv("Google-Playstore.csv", low_memory=False)

# %%
df_gp
# Out:
#                                                   App Name  \
# 0                                   HTTrack Website Copier
# 1                            World War 2: Offline Strategy
# 2                                                   WPSApp
# 3        OfficeSuite - Office, PDF, Word, Excel, PowerP...
# 4                                         Loud Player Free
# ...                                                    ...
# 1118131                                        FleetEnable
# 1118132                                          AutoThink
# 1118133                                        FieldEnable
# 1118134                                       Live Concert
# 1118135                                       Rajput India
#
#                                   App Id       Category  Rating  Rating Count  \
# 0                    com.httrack.android  Communication     3.6        2848.0
# 1                        com.skizze.wwii       Strategy     4.3       17297.0
# 2                  com.themausoft.wpsapp          Tools     4.2      488639.0
# 3                 com.mobisystems.office       Business     4.2     1224420.0
# 4               com.arthelion.loudplayer  Music & Audio     4.2         665.0
# ...                                  ...            ...     ...           ...
# 1118131              com.fleetenable.app   Productivity     NaN           NaN
# 1118132        com.fleetenable.autothink   Productivity     0.0           0.0
# 1118133  com.fieldenable.app.fieldenable       Business     0.0           0.0
# 1118134           com.varbin.liveconcert         Events     0.0           0.0
# 1118135           com.varbin.rajputindia         Social     4.6          81.0
#
#              Installs  Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0            100,000+          100000.0            351560  True    0.0  ...
# 1          1,000,000+         1000000.0           2161778  True    0.0  ...
# 2         50,000,000+        50000000.0          79304739  True    0.0  ...
# 3        100,000,000+       100000000.0         163660067  True    0.0  ...
# 4             50,000+           50000.0             73463  True    0.0  ...
# ...               ...               ...               ...   ...    ...  ...
# 1118131           10+              10.0                10  True    0.0  ...
# 1118132          100+             100.0               127  True    0.0  ...
# 1118133          100+             100.0               282  True    0.0  ...
# 1118134          500+             500.0               986  True    0.0  ...
# 1118135       10,000+           10000.0             18892  True    0.0  ...
#
#              Developer Id            Developer Website  \
# 0            Xavier Roche      http://www.httrack.com/
# 1            Skizze Games          http://stereo7.com/
# 2              TheMauSoft    http://www.themausoft.com
# 3             MobiSystems   http://www.mobisystems.com
# 4             Arthelion92     http://www.arthelion.com
# ...                   ...                          ...
# 1118131      Imaginnovate      http://fleetenable.com/
# 1118132      Imaginnovate  http://www.imaginnovate.com
# 1118133      Imaginnovate  http://www.imaginnovate.com
# 1118134  Varbin Softwares            http://varbin.com
# 1118135  Varbin Softwares            http://varbin.com
#
#                                      Developer Email      Released  \
# 0                          roche+android@httrack.com  Aug 12, 2013
# 1                             Skizze.Games@gmail.com  Jul 19, 2018
# 2                               wpsapp.app@gmail.com   Mar 7, 2016
# 3        support-officesuite-android@mobisystems.com  Dec 22, 2011
# 4                              arthelion92@gmail.com  Sep 24, 2016
# ...                                              ...           ...
# 1118131                     krishna@imaginnovate.com           NaN
# 1118132                     krishna@imaginnovate.com  Nov 26, 2019
# 1118133                 FieldEnable@imaginnovate.com  Apr 30, 2018
# 1118134                     varbinsoftware@gmail.com  Dec 20, 2017
# 1118135                    rajputindia2017@gmail.com  Jun 15, 2017
#
#          Last Updated Content Rating  \
# 0        May 20, 2017       Everyone
# 1        Nov 26, 2020   Everyone 10+
# 2        Oct 21, 2020       Everyone
# 3        Nov 23, 2020       Everyone
# 4        Nov 22, 2020       Everyone
# ...               ...            ...
# 1118131  Jun 30, 2020       Everyone
# 1118132  Nov 13, 2020       Everyone
# 1118133  Nov 30, 2020       Everyone
# 1118134  Dec 20, 2017       Everyone
# 1118135  Sep 27, 2018           Teen
#
#                                             Privacy Policy Ad Supported  \
# 0           http://android.httrack.com/privacy-policy.html        False
# 1           https://www.iubenda.com/privacy-policy/8032781         True
# 2          https://sites.google.com/view/wpsapppolicy/main         True
# 3        http://www.mobisystems.com/mobile/privacy-poli...         True
# 4        http://www.arthelion.com/index.php/fr/android-...        False
# ...                                                    ...          ...
# 1118131                            http://fleetenable.com/        False
# 1118132                        http://www.imaginnovate.com        False
# 1118133                  http://tw.fieldenable.com/privacy        False
# 1118134      http://varbin.com/live-concert-privacy-policy        False
# 1118135                                                NaN         True
#
#         In App Purchases Editors Choice
# 0                  False          False
# 1                   True          False
# 2                  False          False
# 3                   True          False
# 4                  False          False
# ...                  ...            ...
# 1118131            False          False
# 1118132            False          False
# 1118133            False          False
# 1118134            False          False
# 1118135            False          False
#
# [1118136 rows x 23 columns]

# %%
df_merged = pd.merge(df_notna, df_gp[["App Id", "Released", "Last Updated"]], how='inner', left_on='appname', right_on='App Id')

# %%
df_merged = df_merged.drop("App Id", axis=1)

# %%
df_merged
# Out:
#                                  appname  \
# 0                     com.gamebasics.osm
# 1          com.fgol.HungrySharkEvolution
# 2                    com.zynga.livepoker
# 3     ee.dustland.android.dustlandsudoku
# 4             com.miniclip.eightballpool
# ...                                  ...
# 6037        com.berniiiiiiii.logomatchup
# 6038              com.gipnetix.berryking
# 6039                com.smilerlee.jewels
# 6040                   com.geargames.pfp
# 6041        com.daysofwonder.smallworld2
#
#                                               fancyname  \
# 0                           Online Soccer Manager (OSM)
# 1                                Hungry Shark Evolution
# 2     Zynga Poker ? Free Texas Holdem Online Card Games
# 3                                Sudoku - The Clean One
# 4                                           8 Ball Pool
# ...                                                 ...
# 6037                             "Memory" - Memory game
# 6038                                         Berry King
# 6039                                      Jewels Switch
# 6040                           Prehistoric Park Builder
# 6041                                     Small World 2
#
#                     company  purchases  ads  sharesinfo  shareslocation  \
# 0             gamebasics bv        1.0  1.0         0.0             0.0
# 1     ubisoft entertainment        1.0  1.0         0.0             0.0
# 2                     zynga        1.0  1.0         1.0             0.0
# 3           dustland design        1.0  1.0         0.0             0.0
# 4              miniclip.com        1.0  1.0         0.0             0.0
# ...                     ...        ...  ...         ...             ...
# 6037           berni mobile        NaN  NaN         NaN             NaN
# 6038          gameborn inc.        NaN  NaN         NaN             NaN
# 6039           words mobile        NaN  NaN         NaN             NaN
# 6040             gear games        NaN  NaN         NaN             NaN
# 6041                no info        NaN  NaN         NaN             NaN
#
#       unrestrictedinternet  usersinteract  game  ... low_price_item  \
# 0                      0.0            1.0     1  ...           0.59
# 1                      0.0            0.0     1  ...           2.29
# 2                      0.0            1.0     1  ...           0.59
# 3                      0.0            0.0     1  ...           1.89
# 4                      0.0            0.0     1  ...           0.79
# ...                    ...            ...   ...  ...            ...
# 6037                   NaN            NaN     1  ...            NaN
# 6038                   NaN            NaN     1  ...            NaN
# 6039                   NaN            NaN     1  ...            NaN
# 6040                   NaN            NaN     1  ...            NaN
# 6041                   NaN            NaN     1  ...            NaN
#
#       top_price_item  price paidapp rating numberreviews  \
# 0             109.99   free     0.0    4.5     1,656,120
# 1             109.99   free     0.0    4.5     6,495,234
# 2             350.00   free     0.0    4.5     2,315,552
# 3               2.99   free     0.0    4.6         6,639
# 4              99.99   free     0.0    4.5    17,053,699
# ...              ...    ...     ...    ...           ...
# 6037             NaN   free     0.0    4.1       84.91k+
# 6038             NaN   free     0.0    4.4       35.66k+
# 6039             NaN   free     0.0    4.7      728.57k+
# 6040             NaN   free     0.0    4.6      316.56k+
# 6041             NaN   free     0.0    4.3        5.66k+
#
#      cleaned_numberReviews      Released  Last Updated CompanyIsExperienced
# 0                  1656120   Oct 4, 2012  Nov 26, 2020                False
# 1                  6495234  Feb 22, 2013  Oct 27, 2020                 True
# 2                  2315552  Dec 21, 2010  Nov 04, 2020                 True
# 3                     6639  Jul 20, 2017  Oct 29, 2020                False
# 4                 17053699  Jan 23, 2013  Nov 26, 2020                 True
# ...                    ...           ...           ...                  ...
# 6037                 84910  Oct 26, 2012  Nov 28, 2020                 True
# 6038                 35660  Jul 11, 2014  Aug 20, 2020                False
# 6039                728570  Jun 13, 2013  Dec 26, 2019                 True
# 6040                316560  Nov 28, 2012  Feb 17, 2014                 True
# 6041                  5660  Dec 11, 2013  Sep 01, 2020                False
#
# [6042 rows x 24 columns]

# %%
df_companies = df_merged.groupby("company")["company"].count().reset_index(name="count")
df_companies
# Out:
#                                                 company  count
# 0     (<u+c8fc>)<u+c5d4><u+be44><u+c83c><u+d06c><u+b...      1
# 1                       (andrei & aleksandr krupiankou)      1
# 2                                                  0.1%      2
# 3                                              0km apps      1
# 4                                       100500games.org      1
# ...                                                 ...    ...
# 3142                                               zut!      1
# 3143                                        zuuks games      3
# 3144                                    zy puzzle games      1
# 3145                                              zynga     19
# 3146                                   ~princess~games~      1
#
# [3147 rows x 2 columns]

# %%
companiesList = df_companies.to_dict('records')
companiesList
# Out:
# [{'company': '(<u+c8fc>)<u+c5d4><u+be44><u+c83c><u+d06c><u+b9ac><u+c5d0><u+c774><u+d2f0><u+be0c>',
#   'count': 1},
#  {'company': '(andrei & aleksandr krupiankou)', 'count': 1},
#  {'company': '0.1%', 'count': 2},
#  {'company': '0km apps', 'count': 1},
#  {'company': '100500games.org', 'count': 1},
#  {'company': '101xp limited', 'count': 1},
#  {'company': '10p studio', 'count': 2},
#  {'company': '11 bit studios', 'count': 2},
#  {'company': '111%', 'count': 4},
#  {'company': '137studio', 'count': 1},
#  {'company': '1492 studio', 'count': 9},
#  {'company': '17studio', 'count': 1},
#  {'company': '17th pixel', 'count': 1},
#  {'company': '17th pixel poland', 'count': 1},
#  {'company': '1905 games', 'count': 1},
#  {'company': '1bsyl', 'count': 3},
#  {'company': '1coin', 'count': 1},
#  {'company': '1der entertainment', 'count': 1},
#  {'company': '1games', 'count': 1},
#  {'company': '1gravity llc', 'count': 1},
#  {'company': '2048 game', 'count': 1},
#  {'company': '21g.', 'count': 1},
#  {'company': '22cans', 'count': 1},
#  {'company': '231 play', 'count': 1},
#  {'company': '2bros - games for kids', 'count': 2},
#  {'company': '2d boy', 'count': 1},
#  {'company': '2d2b games', 'count': 2},
#  {'company': '2k, inc.', 'count': 1},
#  {'company': '2minds dev', 'count': 1},
#  {'company': '3 minute games', 'count': 2},
#  {'company': '3 sprockets', 'count': 1},
#  {'company': '31x ltd', 'count': 1},
#  {'company': '3583 bytes', 'count': 2},
#  {'company': '36dev', 'count': 1},
#  {'company': '37games', 'count': 1},
#  {'company': '3beesstudio', 'count': 2},
#  {'company': '3catgames', 'count': 1},
#  {'company': '3coderbrain studio', 'count': 3},
#  {'company': '3d creative world', 'count': 1},
#  {'company': '3d futuristic games', 'count': 1},
#  {'company': '3d games here', 'count': 1},
#  {'company': '3dgames', 'count': 2},
#  {'company': '3dinteger', 'count': 2},
#  {'company': '3divi inc.', 'count': 1},
#  {'company': '3dtuning', 'count': 1},
#  {'company': '3match games', 'count': 1},
#  {'company': '4 dimension games', 'count': 1},
#  {'company': '4 game studio', 'count': 1},
#  {'company': '442oons limited', 'count': 1},
#  {'company': '4enjoy game', 'count': 1},
#  {'company': '4th may soft', 'count': 1},
#  {'company': '505 games srl', 'count': 3},
#  {'company': '5amstudios', 'count': 1},
#  {'company': '5daysweekend', 'count': 1},
#  {'company': '5minlab', 'count': 1},
#  {'company': '5th planet games development aps', 'count': 1},
#  {'company': '608factory', 'count': 1},
#  {'company': '6waves', 'count': 1},
#  {'company': '704games', 'count': 1},
#  {'company': '707 interactive', 'count': 2},
#  {'company': '717 pixels', 'count': 1},
#  {'company': '9 to 5 development', 'count': 1},
#  {'company': '999+ games', 'count': 1},
#  {'company': '99games', 'count': 1},
#  {'company': '9m interactive', 'count': 1},
#  {'company': '<u+0001f686> train depo', 'count': 2},
#  {'company': '<u+041b><u+043e><u+043c><u+0430><u+043a><u+0438><u+043d> <u+0414><u+043c><u+0438><u+0442><u+0440><u+0438><u+0439>',
#   'count': 3},
#  {'company': '<u+0433><u+043e><u+043b><u+043e><u+0432><u+043e><u+043b><u+043e><u+043c><u+043a><u+0430> world studio',
#   'count': 2},
#  {'company': '<u+3075><u+3093><u+3069><u+3057><u+30d1><u+30ec><u+30fc><u+30c9>',
#   'count': 1},
#  {'company': '<u+30b6><u+30a4><u+30b6><u+30c3><u+30af><u+30b9><u+682a><u+5f0f><u+4f1a><u+793e>',
#   'count': 1},
#  {'company': '<u+5e7b><u+60f3><u+5a1b><u+6a02>', 'count': 1},
#  {'company': '[adult swim] games', 'count': 1},
#  {'company': 'a creative endeavor ab', 'count': 1},
#  {'company': 'a small game ab', 'count': 1},
#  {'company': 'a thinking ape entertainment ltd.', 'count': 2},
#  {'company': 'a&b development', 'count': 1},
#  {'company': 'a&e television networks mobile', 'count': 1},
#  {'company': 'a-s-g', 'count': 4},
#  {'company': 'a-star software llc', 'count': 1},
#  {'company': 'aart bik', 'count': 2},
#  {'company': 'ab volvo', 'count': 1},
#  {'company': 'abgames89', 'count': 1},
#  {'company': 'abilix', 'count': 1},
#  {'company': 'abradoodle games - fun bingo games', 'count': 1},
#  {'company': 'absolute games : free bingo games', 'count': 1},
#  {'company': 'absolutist ltd', 'count': 3},
#  {'company': 'absomech', 'count': 2},
#  {'company': 'abstract software inc.', 'count': 1},
#  {'company': 'abstractart', 'count': 1},
#  {'company': 'abuzz', 'count': 7},
#  {'company': 'ace viral', 'count': 5},
#  {'company': 'achro games', 'count': 1},
#  {'company': 'acoin games', 'count': 2},
#  {'company': 'acr21', 'count': 1},
#  {'company': 'act games', 'count': 1},
#  {'company': 'actions', 'count': 1},
#  {'company': 'activision publishing, inc.', 'count': 1},
#  {'company': 'acute games', 'count': 1},
#  {'company': 'addict puzzle games', 'count': 1},
#  {'company': 'adriaan de jongh', 'count': 1},
#  {'company': 'advanced weapon tech', 'count': 1},
#  {'company': 'adventure cat, llc', 'count': 1},
#  {'company': 'adventure islands', 'count': 2},
#  {'company': 'ae magwin: free casino slot machines bingo games', 'count': 1},
#  {'company': 'aegis interactive, llc', 'count': 1},
#  {'company': 'aeria canada', 'count': 3},
#  {'company': 'afksoft', 'count': 1},
#  {'company': 'agaming+', 'count': 4},
#  {'company': 'aged studio limited', 'count': 1},
#  {'company': 'agens as', 'count': 1},
#  {'company': 'ahoy games', 'count': 1},
#  {'company': 'ai factory limited', 'count': 16},
#  {'company': 'aidem media', 'count': 1},
#  {'company': 'airblade studio', 'count': 1},
#  {'company': 'ajoy lab games', 'count': 1},
#  {'company': 'akadem', 'count': 1},
#  {'company': 'akop karapetyan', 'count': 1},
#  {'company': 'akpublish pty ltd', 'count': 3},
#  {'company': 'aladin interactive', 'count': 2},
#  {'company': 'alcamasoft', 'count': 1},
#  {'company': 'alda games', 'count': 4},
#  {'company': 'aleaf games', 'count': 2},
#  {'company': 'aleksdev', 'count': 1},
#  {'company': 'alex naronov', 'count': 2},
#  {'company': 'alexander barbyshev', 'count': 1},
#  {'company': 'alexander byzov', 'count': 1},
#  {'company': 'alexandre salou', 'count': 1},
#  {'company': 'alexei anoshenko', 'count': 1},
#  {'company': 'alexey korobov', 'count': 1},
#  {'company': 'alexplay llc', 'count': 3},
#  {'company': 'aliaksandr uvarau', 'count': 2},
#  {'company': 'alienforce', 'count': 1},
#  {'company': 'allmobile', 'count': 1},
#  {'company': 'allstar games', 'count': 1},
#  {'company': 'alma games', 'count': 1},
#  {'company': 'alp games', 'count': 2},
#  {'company': 'alper sarikaya', 'count': 3},
#  {'company': 'alpha intl. it group', 'count': 1},
#  {'company': 'alphaquest game studio', 'count': 2},
#  {'company': 'altshift', 'count': 1},
#  {'company': 'amanita design', 'count': 2},
#  {'company': 'amanotes', 'count': 8},
#  {'company': 'amaya kids - learning games for 3-5 years old llc', 'count': 1},
#  {'company': 'ambition co.,ltd.', 'count': 1},
#  {'company': 'amdroid', 'count': 1},
#  {'company': 'ammonite studio', 'count': 1},
#  {'company': 'amt games ltd.', 'count': 1},
#  {'company': 'amt games publishing limited', 'count': 1},
#  {'company': 'amusinggame', 'count': 1},
#  {'company': 'ancient games d s', 'count': 1},
#  {'company': 'anderson horita', 'count': 1},
#  {'company': 'andrea sabbatini', 'count': 2},
#  {'company': 'andream', 'count': 2},
#  {'company': 'andreas grothe', 'count': 1},
#  {'company': 'andrey rebrik', 'count': 1},
#  {'company': 'andrey solovyev', 'count': 10},
#  {'company': 'androbaby', 'count': 5},
#  {'company': 'androbros', 'count': 2},
#  {'company': 'android pixels', 'count': 1},
#  {'company': 'andromedagames', 'count': 1},
#  {'company': 'androyal', 'count': 1},
#  {'company': 'andrzej chomiak', 'count': 1},
#  {'company': 'angela he', 'count': 2},
#  {'company': 'angry mob games', 'count': 1},
#  {'company': 'anibox', 'count': 2},
#  {'company': 'anima_games', 'count': 1},
#  {'company': 'animoca', 'count': 1},
#  {'company': 'animoca brands', 'count': 1},
#  {'company': 'anion software', 'count': 1},
#  {'company': 'aniplex inc.', 'count': 1},
#  {'company': 'anirudh rahul', 'count': 1},
#  {'company': 'anji games', 'count': 1},
#  {'company': 'ankama games', 'count': 7},
#  {'company': 'annapurna interactive', 'count': 2},
#  {'company': 'annd consulting games', 'count': 1},
#  {'company': 'antithesis design', 'count': 1},
#  {'company': 'antoine latour', 'count': 1},
#  {'company': 'anuken', 'count': 1},
#  {'company': 'anuman', 'count': 2},
#  {'company': 'ape studios', 'count': 1},
#  {'company': 'apesoup', 'count': 1},
#  {'company': 'apis games', 'count': 1},
#  {'company': 'aplity', 'count': 2},
#  {'company': 'apnax games', 'count': 3},
#  {'company': 'app design company uk', 'count': 1},
#  {'company': 'app family kids - games for boys and girls', 'count': 4},
#  {'company': 'app holdings', 'count': 17},
#  {'company': 'app reactor 3d', 'count': 1},
#  {'company': 'appa47', 'count': 1},
#  {'company': 'appbox media', 'count': 1},
#  {'company': 'appcraft llc', 'count': 1},
#  {'company': 'appdeko games', 'count': 1},
#  {'company': 'appgo', 'count': 1},
#  {'company': 'appidea capital ltd', 'count': 1},
#  {'company': 'appilis llc', 'count': 1},
#  {'company': 'appissimo eu', 'count': 1},
#  {'company': 'applabs', 'count': 1},
#  {'company': 'applications-b', 'count': 3},
#  {'company': 'applicattura michal walaszczyk', 'count': 1},
#  {'company': 'applife limited', 'count': 1},
#  {'company': 'appliss inc.', 'count': 1},
#  {'company': 'appmeisters', 'count': 3},
#  {'company': 'appnormal.com bv', 'count': 1},
#  {'company': 'appon innovate', 'count': 5},
#  {'company': 'appquantum', 'count': 1},
#  {'company': 'appquiz', 'count': 13},
#  {'company': 'apprize', 'count': 3},
#  {'company': 'apprope', 'count': 1},
#  {'company': 'apps gempro', 'count': 1},
#  {'company': 'apps2us studios', 'count': 1},
#  {'company': 'appscraft', 'count': 2},
#  {'company': 'appsir, inc.', 'count': 1},
#  {'company': 'appsoft technology ?', 'count': 1},
#  {'company': 'appstronaut studios', 'count': 1},
#  {'company': 'appsx', 'count': 1},
#  {'company': 'appszoo', 'count': 2},
#  {'company': 'appteeka vr games', 'count': 2},
#  {'company': 'apptornado', 'count': 1},
#  {'company': 'apptornado games', 'count': 2},
#  {'company': 'appvertising', 'count': 1},
#  {'company': 'appxplore (icandy)', 'count': 5},
#  {'company': 'appynation ltd.', 'count': 2},
#  {'company': 'aquiris game studio s.a', 'count': 1},
#  {'company': 'arcade game maker', 'count': 2},
#  {'company': 'archiact', 'count': 1},
#  {'company': 'archison', 'count': 1},
#  {'company': 'arclite systems', 'count': 1},
#  {'company': 'area730 entertainment', 'count': 1},
#  {'company': 'argeworld', 'count': 1},
#  {'company': 'aristokraken', 'count': 1},
#  {'company': 'arithmetic love series', 'count': 1},
#  {'company': 'arkadium games', 'count': 1},
#  {'company': 'arkavis', 'count': 1},
#  {'company': 'armor games', 'count': 7},
#  {'company': 'arnold rauers', 'count': 3},
#  {'company': 'arqew', 'count': 1},
#  {'company': 'art in games', 'count': 1},
#  {'company': 'artem kotov', 'count': 2},
#  {'company': 'artem naumov', 'count': 1},
#  {'company': 'arteoning', 'count': 1},
#  {'company': 'artgs', 'count': 1},
#  {'company': 'artifex mundi', 'count': 1},
#  {'company': 'artik games', 'count': 2},
#  {'company': 'artix entertainment llc', 'count': 1},
#  {'company': 'artstorm', 'count': 3},
#  {'company': 'asantee', 'count': 1},
#  {'company': 'asgardsoft', 'count': 1},
#  {'company': 'asher vollmer', 'count': 2},
#  {'company': 'asmodee digital', 'count': 9},
#  {'company': 'asobimo, inc.', 'count': 1},
#  {'company': 'aspyr media, inc.', 'count': 1},
#  {'company': 'assassin games', 'count': 1},
#  {'company': 'asteroid games 3d', 'count': 1},
#  {'company': 'astragon entertainment gmbh', 'count': 9},
#  {'company': 'at2 game studio', 'count': 1},
#  {'company': 'atari, inc.', 'count': 2},
#  {'company': 'ateam inc.', 'count': 1},
#  {'company': 'athena studio', 'count': 1},
#  {'company': 'atom games ent.', 'count': 2},
#  {'company': 'atomic locs', 'count': 1},
#  {'company': 'atorch', 'count': 1},
#  {'company': 'atvis ab', 'count': 1},
#  {'company': 'aurastudio', 'count': 1},
#  {'company': 'auxbrain inc', 'count': 1},
#  {'company': 'avalon-games', 'count': 2},
#  {'company': 'avecreation', 'count': 3},
#  {'company': 'avelog', 'count': 2},
#  {'company': 'aviador / inmobile', 'count': 2},
#  {'company': 'avid.ly', 'count': 1},
#  {'company': 'avix', 'count': 1},
#  {'company': 'avsey', 'count': 1},
#  {'company': 'awem games limited', 'count': 1},
#  {'company': 'awesome action games', 'count': 1},
#  {'company': 'axesinmotion casual', 'count': 1},
#  {'company': 'axesinmotion classics', 'count': 1},
#  {'company': 'axesinmotion racing', 'count': 5},
#  {'company': 'axfn', 'count': 1},
#  {'company': 'axgamesoft', 'count': 1},
#  {'company': 'axlebolt', 'count': 2},
#  {'company': 'ayasis', 'count': 1},
#  {'company': 'azamatika', 'count': 1},
#  {'company': 'azul multimedia', 'count': 1},
#  {'company': 'azur interactive games limited', 'count': 12},
#  {'company': 'b-alive gmbh', 'count': 1},
#  {'company': 'b-interaktive', 'count': 1},
#  {'company': 'b2a apps', 'count': 1},
#  {'company': 'babeltime us', 'count': 1},
#  {'company': 'baby care games', 'count': 1},
#  {'company': 'babybus', 'count': 11},
#  {'company': 'babybus kids games', 'count': 15},
#  {'company': 'backflip studios', 'count': 1},
#  {'company': 'backflip studios, llc', 'count': 1},
#  {'company': 'bad crane', 'count': 2},
#  {'company': 'bad developer games', 'count': 1},
#  {'company': 'bad idea studio', 'count': 1},
#  {'company': 'badsnowball limited', 'count': 1},
#  {'company': 'baibai, inc.', 'count': 1},
#  {'company': 'bake450 inc.', 'count': 1},
#  {'company': 'baklabs', 'count': 3},
#  {'company': 'balicheckers', 'count': 1},
#  {'company': 'ball games', 'count': 1},
#  {'company': 'balloon island', 'count': 1},
#  {'company': 'bambo studio', 'count': 5},
#  {'company': 'banana & co.', 'count': 2},
#  {'company': 'banana development', 'count': 1},
#  {'company': 'bandai namco entertainment america inc.', 'count': 2},
#  {'company': 'bandai namco entertainment europe', 'count': 4},
#  {'company': 'bandai namco entertainment inc.', 'count': 5},
#  {'company': 'barabapps', 'count': 2},
#  {'company': 'barracuda fish games', 'count': 1},
#  {'company': 'bart bonte', 'count': 8},
#  {'company': 'batalsoft music apps', 'count': 1},
#  {'company': 'batoki - best apps for toddlers and kids', 'count': 2},
#  {'company': 'battle creek games', 'count': 1},
#  {'company': 'battlecry', 'count': 1},
#  {'company': 'bayland blue', 'count': 1},
#  {'company': 'bazon', 'count': 1},
#  {'company': 'bazooka studio', 'count': 1},
#  {'company': 'bbc worldwide (ltd)', 'count': 1},
#  {'company': 'bbg entertainment', 'count': 1},
#  {'company': 'beach bum ltd.', 'count': 1},
#  {'company': 'beamdog', 'count': 1},
#  {'company': 'bear hug media inc', 'count': 2},
#  {'company': 'bearbit studios b.v.', 'count': 2},
#  {'company': 'beautiful free mahjong games by difference games', 'count': 1},
#  {'company': 'beautifun games', 'count': 1},
#  {'company': 'beauty girls', 'count': 1},
#  {'company': 'beauty inc', 'count': 1},
#  {'company': 'bedtime digital games', 'count': 1},
#  {'company': 'bee square games', 'count': 1},
#  {'company': 'beer money games!', 'count': 1},
#  {'company': 'beetles games studio', 'count': 1},
#  {'company': 'beeworks games', 'count': 1},
#  {'company': 'beige elephant', 'count': 1},
#  {'company': 'beingame limited', 'count': 1},
#  {'company': 'beiz', 'count': 2},
#  {'company': 'bekko.com', 'count': 2},
#  {'company': 'belka games', 'count': 3},
#  {'company': 'benjamin lochmann new media gmbh', 'count': 1},
#  {'company': 'benji bananas', 'count': 2},
#  {'company': 'beno?t freslon', 'count': 1},
#  {'company': 'beresnev games', 'count': 2},
#  {'company': 'berni mobile', 'count': 4},
#  {'company': 'bertheussen it', 'count': 3},
#  {'company': 'best bingo casino games', 'count': 1},
#  {'company': 'best cool and fun games', 'count': 1},
#  {'company': 'best free games inc.', 'count': 1},
#  {'company': 'best photo apps', 'count': 1},
#  {'company': 'bestfriendsteam', 'count': 1},
#  {'company': 'betacom (uk) s.a.', 'count': 1},
#  {'company': 'betdon', 'count': 1},
#  {'company': 'bethesda softworks llc', 'count': 3},
#  {'company': 'betis', 'count': 1},
#  {'company': 'better life - color and draw', 'count': 4},
#  {'company': 'better multiplayer games', 'count': 1},
#  {'company': 'better world games', 'count': 1},
#  {'company': 'bf game', 'count': 1},
#  {'company': 'bicycle playing cards', 'count': 1},
#  {'company': 'big bad bros', 'count': 1},
#  {'company': 'big bear entertainment', 'count': 1},
#  {'company': 'big blue bubble', 'count': 1},
#  {'company': 'big brain kraken', 'count': 1},
#  {'company': 'big bull games', 'count': 1},
#  {'company': 'big cake group limited', 'count': 1},
#  {'company': 'big cat studio - we make brain games', 'count': 2},
#  {'company': 'big duck games llc', 'count': 6},
#  {'company': 'big fat simulations inc.', 'count': 2},
#  {'company': 'big fish games', 'count': 10},
#  {'company': 'big frost games', 'count': 1},
#  {'company': 'bigbeep', 'count': 3},
#  {'company': 'bigdog games', 'count': 1},
#  {'company': 'bigger games', 'count': 1},
#  {'company': 'bigpoint', 'count': 1},
#  {'company': 'bigstar games', 'count': 2},
#  {'company': 'bigumaku ltd', 'count': 1},
#  {'company': 'bigwig media', 'count': 2},
#  {'company': 'bigzur', 'count': 2},
#  {'company': 'bilkon', 'count': 1},
#  {'company': 'bimi boo kids - games for boys and girls llc', 'count': 10},
#  {'company': 'binary guilt software', 'count': 1},
#  {'company': 'bintagogames', 'count': 1},
#  {'company': 'birdy dog studio', 'count': 1},
#  {'company': 'bit free games', 'count': 1},
#  {'company': 'bit of game', 'count': 1},
#  {'company': 'bit.games', 'count': 1},
#  {'company': 'bitbros inc.', 'count': 1},
#  {'company': 'bitcoin aliens', 'count': 1},
#  {'company': 'bitmango', 'count': 23},
#  {'company': 'bizo mobile', 'count': 1},
#  {'company': 'bj?rn bartels', 'count': 1},
#  {'company': 'bkg studio', 'count': 1},
#  {'company': 'black bears', 'count': 2},
#  {'company': 'black games', 'count': 1},
#  {'company': 'black maple games', 'count': 4},
#  {'company': 'black panther', 'count': 1},
#  {'company': 'black shield studio', 'count': 1},
#  {'company': 'black vein productions, inc.', 'count': 1},
#  {'company': 'blacklight studio games', 'count': 2},
#  {'company': 'blade-x games', 'count': 1},
#  {'company': 'blankmediagames', 'count': 1},
#  {'company': 'blastmatchgames', 'count': 1},
#  {'company': 'blayze games, l.l.c.', 'count': 2},
#  {'company': 'blindflug studios ag', 'count': 2},
#  {'company': 'bling bling games gmbh', 'count': 2},
#  {'company': 'blitwise productions, llc', 'count': 1},
#  {'company': 'blizzard entertainment, inc.', 'count': 2},
#  {'company': 'block puzzle free games', 'count': 1},
#  {'company': 'block puzzle games 2018', 'count': 1},
#  {'company': 'block puzzle jewel games', 'count': 1},
#  {'company': 'blockman go studio', 'count': 6},
#  {'company': 'blockot games', 'count': 2},
#  {'company': 'bloom digital', 'count': 1},
#  {'company': 'bloop games', 'count': 3},
#  {'company': 'blue boat co., ltd.', 'count': 2},
#  {'company': 'blue bottle games, llc', 'count': 1},
#  {'company': 'blue brain games s.r.o.', 'count': 1},
#  {'company': 'blue cow entertainment', 'count': 1},
#  {'company': 'blue wave', 'count': 1},
#  {'company': 'blue wizard digital lp', 'count': 1},
#  {'company': 'bluebell lush interactive limited', 'count': 3},
#  {'company': 'blueflower', 'count': 1},
#  {'company': 'blueriver interactive', 'count': 1},
#  {'company': 'blyts', 'count': 3},
#  {'company': 'bo long', 'count': 1},
#  {'company': 'bodegames', 'count': 1},
#  {'company': 'bohemia interactive a.s.', 'count': 1},
#  {'company': 'bojan klabjan', 'count': 1},
#  {'company': 'bombay play', 'count': 1},
#  {'company': 'bombsight games', 'count': 1},
#  {'company': 'bon games', 'count': 1},
#  {'company': 'bonbeart games', 'count': 4},
#  {'company': 'bonbongame.com', 'count': 2},
#  {'company': 'boneapps', 'count': 1},
#  {'company': 'bonusxp, inc.', 'count': 1},
#  {'company': 'book n app - papplishing house gmbh', 'count': 1},
#  {'company': 'boombit games', 'count': 7},
#  {'company': 'boomhits', 'count': 1},
#  {'company': 'boomware technologies', 'count': 2},
#  {'company': 'boss fight entertainment', 'count': 1},
#  {'company': 'botensoft', 'count': 1},
#  {'company': 'bouland games', 'count': 1},
#  {'company': 'boze games', 'count': 1},
#  {'company': 'bp game studio', 'count': 2},
#  {'company': 'brad erkkila', 'count': 3},
#  {'company': 'brainit games', 'count': 1},
#  {'company': 'brainium studios', 'count': 5},
#  {'company': 'brainy owl games', 'count': 1},
#  {'company': 'brandon li', 'count': 1},
#  {'company': 'brandon stecklein', 'count': 2},
#  {'company': 'bravestars games', 'count': 4},
#  {'company': 'bravetale', 'count': 1},
#  {'company': 'breakcoder', 'count': 1},
#  {'company': 'breaker', 'count': 2},
#  {'company': 'bridge base online', 'count': 1},
#  {'company': 'brilliant gamez', 'count': 2},
#  {'company': 'brilliant labs limited', 'count': 1},
#  {'company': 'broken diamond', 'count': 2},
#  {'company': 'brothers apps and games', 'count': 1},
#  {'company': 'brownmonster limited', 'count': 2},
#  {'company': 'bruno fargnoli', 'count': 1},
#  {'company': 'brutus games', 'count': 1},
#  {'company': 'bryce summer', 'count': 1},
#  {'company': 'bubble joy', 'count': 1},
#  {'company': 'bubble puzzle games', 'count': 1},
#  {'company': 'bubble quiz games', 'count': 4},
#  {'company': 'bubble shooter', 'count': 2},
#  {'company': 'bubble shooter <u+30b9><u+30bf><u+30b8><u+30aa>', 'count': 1},
#  {'company': 'bubble shooter artworks', 'count': 4},
#  {'company': 'bubble shooter games by ilyon', 'count': 2},
#  {'company': 'budge studios', 'count': 17},
#  {'company': 'buff studio co.,ltd.', 'count': 6},
#  {'company': 'build block studio', 'count': 1},
#  {'company': 'bun gun', 'count': 1},
#  {'company': 'bun studio', 'count': 1},
#  {'company': 'bungie, inc.', 'count': 1},
#  {'company': 'buscoldapp', 'count': 4},
#  {'company': 'bushiroad international pte ltd_', 'count': 1},
#  {'company': 'butterflyware games', 'count': 1},
#  {'company': 'bweb media', 'count': 4},
#  {'company': 'bycodec games', 'count': 2},
#  {'company': 'byril', 'count': 4},
#  {'company': 'byteghoul games', 'count': 1},
#  {'company': 'bytesequencing.com,llc', 'count': 1},
#  {'company': 'bytro labs', 'count': 2},
#  {'company': 'byv', 'count': 5},
#  {'company': 'c4cat entertainment limited', 'count': 1},
#  {'company': 'cabbiegames', 'count': 1},
#  {'company': 'cableek games', 'count': 1},
#  {'company': 'cadev games', 'count': 4},
#  {'company': 'caffeinemonster', 'count': 1},
#  {'company': 'caique cunha pereira', 'count': 1},
#  {'company': 'camel games, inc', 'count': 3},
#  {'company': 'camerapps', 'count': 1},
#  {'company': 'camex games', 'count': 1},
#  {'company': 'camouflaj, llc', 'count': 1},
#  {'company': 'canarydroid', 'count': 8},
#  {'company': 'candivore', 'count': 1},
#  {'company': 'candy bubble studio', 'count': 1},
#  {'company': 'candy factory game', 'count': 1},
#  {'company': 'candy mobile', 'count': 3},
#  {'company': 'candy rufus games', 'count': 2},
#  {'company': 'candy soft, inc', 'count': 1},
#  {'company': 'candywriter, llc', 'count': 1},
#  {'company': 'capcom co., ltd.', 'count': 1},
#  {'company': 'card games, inc', 'count': 2},
#  {'company': 'carlos sala samper', 'count': 1},
#  {'company': 'carolgames', 'count': 3},
#  {'company': 'cartoon network', 'count': 1},
#  {'company': 'cartoon network emea', 'count': 1},
#  {'company': 'carx technologies', 'count': 4},
#  {'company': 'casual azur games', 'count': 5},
#  {'company': 'casual joy games', 'count': 1},
#  {'company': 'casual monster', 'count': 1},
#  {'company': 'casualino games', 'count': 1},
#  {'company': 'cat games studio', 'count': 4},
#  {'company': 'cat studio', 'count': 2},
#  {'company': 'catsbit games', 'count': 2},
#  {'company': 'celsius online', 'count': 1},
#  {'company': 'celtic spear', 'count': 2},
#  {'company': 'century game (diandian interactive)', 'count': 4},
#  {'company': 'cerebralfix', 'count': 1},
#  {'company': 'cge digital', 'count': 3},
#  {'company': 'chapas games', 'count': 1},
#  {'company': 'check-in games', 'count': 1},
#  {'company': 'cheetah games', 'count': 3},
#  {'company': 'chef.gs', 'count': 1},
#  {'company': 'cheritz co., ltd', 'count': 1},
#  {'company': 'cherrypick games', 'count': 2},
#  {'company': 'chess & checkers lukasz oktaba', 'count': 3},
#  {'company': 'chess king', 'count': 4},
#  {'company': 'chess prince', 'count': 1},
#  {'company': 'chess.com', 'count': 3},
#  {'company': 'chess24', 'count': 1},
#  {'company': 'chessfriends.com', 'count': 2},
#  {'company': 'chessify', 'count': 1},
#  {'company': 'chibig', 'count': 1},
#  {'company': 'chilled mouse', 'count': 1},
#  {'company': 'chillingo', 'count': 1},
#  {'company': 'chillyroom', 'count': 1},
#  {'company': 'chimpworks', 'count': 1},
#  {'company': 'chinacit.com', 'count': 1},
#  {'company': 'choice of games llc', 'count': 8},
#  {'company': 'chouic', 'count': 2},
#  {'company': 'chuang cool entertainment', 'count': 1},
#  {'company': 'chucklefish limited', 'count': 1},
#  {'company': 'ciagram co., ltd.', 'count': 1},
#  {'company': 'ciliz co. ltd.', 'count': 1},
#  {'company': 'cireracake', 'count': 1},
#  {'company': 'city games llc', 'count': 2},
#  {'company': 'clancy studios', 'count': 1},
#  {'company': 'clapfoot inc.', 'count': 4},
#  {'company': 'classic arcade games', 'count': 1},
#  {'company': 'classic cards', 'count': 1},
#  {'company': 'classic puzzle block game', 'count': 1},
#  {'company': 'classic puzzle games studio', 'count': 1},
#  {'company': 'classic solitaire games inc', 'count': 2},
#  {'company': 'clegames inc.', 'count': 1},
#  {'company': 'clement vitroly', 'count': 2},
#  {'company': 'clementoni s.p.a.', 'count': 2},
#  {'company': 'clever apps pte. ltd.', 'count': 1},
#  {'company': 'cleverbit', 'count': 2},
#  {'company': 'clickteam usa llc', 'count': 2},
#  {'company': 'clockstone studio', 'count': 1},
#  {'company': 'clockwatchers inc', 'count': 2},
#  {'company': 'cloudcade, inc.', 'count': 1},
#  {'company': 'cloudmacaca inc.', 'count': 1},
#  {'company': 'cloudteam', 'count': 1},
#  {'company': 'clown games', 'count': 6},
#  {'company': 'cnc apps', 'count': 1},
#  {'company': 'cobramobilegaming', 'count': 1},
#  {'company': 'coco play by tabtale', 'count': 29},
#  {'company': 'cocoa gaming', 'count': 1},
#  {'company': 'cocosola', 'count': 1},
#  {'company': 'coda masters', 'count': 1},
#  {'company': 'codebits interactive', 'count': 1},
#  {'company': 'codebrew games', 'count': 2},
#  {'company': 'codemasters software company ltd', 'count': 2},
#  {'company': 'codevlyca', 'count': 1},
#  {'company': 'codex7 games', 'count': 1},
#  {'company': 'codigames', 'count': 6},
#  {'company': 'coffee break games', 'count': 1},
#  {'company': 'coffee stain publishing', 'count': 1},
#  {'company': 'cold soda', 'count': 1},
#  {'company': 'coldfire games gmbh', 'count': 1},
#  {'company': 'coller', 'count': 1},
#  {'company': 'color apps for free', 'count': 2},
#  {'company': 'color switch phoenix llc', 'count': 1},
#  {'company': 'colorfit', 'count': 2},
#  {'company': 'colorful piano', 'count': 1},
#  {'company': 'coloring by number - pixel art games : next tech', 'count': 1},
#  {'company': 'coloring games', 'count': 3},
#  {'company': 'colorjoy', 'count': 2},
#  {'company': 'colortime & puzzletime', 'count': 2},
#  {'company': 'colossal entertainment', 'count': 1},
#  {'company': 'com2us', 'count': 6},
#  {'company': 'com2wordsgame', 'count': 1},
#  {'company': 'comic book reese', 'count': 1},
#  {'company': 'computersmith', 'count': 1},
#  {'company': 'conceptis ltd.', 'count': 4},
#  {'company': 'concrete software, inc.', 'count': 2},
#  {'company': 'connect word games', 'count': 2},
#  {'company': 'cookapps', 'count': 3},
#  {'company': 'cool awesome fun', 'count': 1},
#  {'company': 'cool cherry trees', 'count': 2},
#  {'company': 'cool future', 'count': 1},
#  {'company': 'cool games - puzzle', 'count': 1},
#  {'company': 'coolstudios', 'count': 3},
#  {'company': 'cooyou', 'count': 1},
#  {'company': 'cornago stefano', 'count': 2},
#  {'company': 'cosmo game', 'count': 1},
#  {'company': 'cotrinoapps app development', 'count': 1},
#  {'company': 'countryside games', 'count': 1},
#  {'company': 'coworkdream', 'count': 1},
#  {'company': 'cpu studio', 'count': 1},
#  {'company': 'crafting and building games for girls adventure', 'count': 4},
#  {'company': 'craneballs', 'count': 1},
#  {'company': 'crashinvaders', 'count': 1},
#  {'company': 'crazy camp media', 'count': 1},
#  {'company': 'crazy cats', 'count': 1},
#  {'company': 'crazy game developer', 'count': 1},
#  {'company': 'crazy games lab', 'count': 1},
#  {'company': 'crazy labs by tabtale', 'count': 16},
#  {'company': 'crazy maple studio dev', 'count': 1},
#  {'company': 'crazy owl', 'count': 1},
#  {'company': 'crazy panda limited', 'count': 2},
#  {'company': 'crazyplex llc', 'count': 1},
#  {'company': 'creapptive co., ltd.', 'count': 1},
#  {'company': 'creative apps', 'count': 2},
#  {'company': 'creative bee', 'count': 1},
#  {'company': 'creative friends b.v.', 'count': 1},
#  {'company': 'creative mobile', 'count': 1},
#  {'company': 'creative mobile games', 'count': 4},
#  {'company': 'creative robot', 'count': 1},
#  {'company': 'crescent moon games', 'count': 2},
#  {'company': 'crimson moon entertainment llc', 'count': 1},
#  {'company': 'crimson pine games', 'count': 4},
#  {'company': 'critical force ltd.', 'count': 1},
#  {'company': 'critical hit software', 'count': 1},
#  {'company': 'cross field inc.', 'count': 4},
#  {'company': 'crossconstruct', 'count': 2},
#  {'company': 'crowdstar inc', 'count': 2},
#  {'company': 'crozzle ivs', 'count': 1},
#  {'company': 'crunchyroll games', 'count': 1},
#  {'company': 'crystal squid', 'count': 1},
#  {'company': 'cube software', 'count': 1},
#  {'company': 'cubecube sports', 'count': 1},
#  {'company': 'curacha games', 'count': 1},
#  {'company': 'curious  labs', 'count': 1},
#  {'company': 'currygames', 'count': 4},
#  {'company': 'customplay llc', 'count': 1},
#  {'company': 'cute mobile games', 'count': 1},
#  {'company': 'cutefun', 'count': 1},
#  {'company': 'cvi games', 'count': 2},
#  {'company': 'cyanfox development', 'count': 1},
#  {'company': 'cybird', 'count': 1},
#  {'company': 'cygames, inc.', 'count': 1},
#  {'company': 'd&d dream', 'count': 3},
#  {'company': 'd-games apps', 'count': 1},
#  {'company': 'd.g. cedartree project ltd', 'count': 1},
#  {'company': 'd3 go!', 'count': 3},
#  {'company': 'daerisoft', 'count': 4},
#  {'company': 'daf', 'count': 1},
#  {'company': 'daigo studio', 'count': 1},
#  {'company': 'damian bernardi', 'count': 1},
#  {'company': 'dan vogt', 'count': 1},
#  {'company': 'dan-ball', 'count': 2},
#  {'company': 'danchoco', 'count': 1},
#  {'company': 'dangerous derk interactive ltd', 'count': 1},
#  {'company': 'danidevstuff', 'count': 1},
#  {'company': 'danko lab.', 'count': 1},
#  {'company': 'danny cruz', 'count': 1},
#  {'company': 'dare to play', 'count': 1},
#  {'company': 'dark eye', 'count': 1},
#  {'company': 'darong studio', 'count': 1},
#  {'company': 'dasuppastudios', 'count': 1},
#  {'company': 'dataverse entertainment', 'count': 2},
#  {'company': 'dave bollinger', 'count': 1},
#  {'company': 'david zobrist', 'count': 1},
#  {'company': 'davide berra', 'count': 1},
#  {'company': 'dawid myslak', 'count': 2},
#  {'company': 'dawinstone', 'count': 1},
#  {'company': 'dawsn interactive studios', 'count': 1},
#  {'company': 'day-off games', 'count': 1},
#  {'company': 'daybreak industries', 'count': 1},
#  {'company': 'daygames', 'count': 1},
#  {'company': 'dear villagers', 'count': 2},
#  {'company': 'deca games', 'count': 1},
#  {'company': 'deca_games', 'count': 1},
#  {'company': 'decipixel games', 'count': 1},
#  {'company': 'dedalord', 'count': 1},
#  {'company': 'deemedya inc', 'count': 4},
#  {'company': 'deep byte studios srl', 'count': 1},
#  {'company': 'deep silver', 'count': 1},
#  {'company': 'deer cat', 'count': 1},
#  {'company': 'defiant development', 'count': 1},
#  {'company': 'delight games', 'count': 3},
#  {'company': 'deltamedia', 'count': 1},
#  {'company': 'dena co., ltd.', 'count': 1},
#  {'company': 'dena corp.', 'count': 1},
#  {'company': 'denigorgames', 'count': 1},
#  {'company': 'denis lapiner', 'count': 1},
#  {'company': 'deuski games', 'count': 1},
#  {'company': 'deutsche bahn', 'count': 1},
#  {'company': 'dev null', 'count': 1},
#  {'company': 'devcro', 'count': 2},
#  {'company': 'devm games se', 'count': 3},
#  {'company': 'devolverdigital', 'count': 3},
#  {'company': 'devsisters corporation', 'count': 2},
#  {'company': 'devsquare', 'count': 1},
#  {'company': 'dfl deutsche fu?ball liga gmbh', 'count': 1},
#  {'company': 'dg&g', 'count': 1},
#  {'company': 'dgn games - free slots casino', 'count': 1},
#  {'company': 'dh-games', 'count': 1},
#  {'company': 'dh3 games', 'count': 2},
#  {'company': 'dhgames', 'count': 1},
#  {'company': 'dhs games', 'count': 1},
#  {'company': 'diced pixel, llc', 'count': 1},
#  {'company': 'didactoons', 'count': 1},
#  {'company': 'digi-chain games', 'count': 3},
#  {'company': 'digigo', 'count': 1},
#  {'company': 'digital extremes', 'count': 1},
#  {'company': 'digital legends entertainment sl', 'count': 1},
#  {'company': 'digital melody', 'count': 3},
#  {'company': 'digital panda studios', 'count': 1},
#  {'company': 'digital royal studio', 'count': 1},
#  {'company': 'digital smoke llc', 'count': 1},
#  {'company': 'digitaleagle', 'count': 10},
#  {'company': 'digitalgoal ltd', 'count': 1},
#  {'company': 'dignity games', 'count': 4},
#  {'company': 'dingo games', 'count': 3},
#  {'company': 'dino go', 'count': 1},
#  {'company': 'dinosaur polo club', 'count': 1},
#  {'company': 'dire wolf digital', 'count': 1},
#  {'company': 'dirtybit', 'count': 1},
#  {'company': 'disney', 'count': 6},
#  {'company': 'distinct media', 'count': 1},
#  {'company': 'distinctdev, inc.', 'count': 1},
#  {'company': 'distinctive games', 'count': 1},
#  {'company': 'divins mathew', 'count': 1},
#  {'company': 'divmob', 'count': 2},
#  {'company': 'djinnworks gmbh', 'count': 15},
#  {'company': 'dmitsoft', 'count': 5},
#  {'company': 'dmnk games', 'count': 1},
#  {'company': 'dns studio', 'count': 3},
#  {'company': 'dodreams ltd.', 'count': 2},
#  {'company': 'dogbyte games', 'count': 3},
#  {'company': 'doing studio', 'count': 3},
#  {'company': 'dolphin emulator', 'count': 1},
#  {'company': 'dolphinapp', 'count': 1},
#  {'company': 'don naipe', 'count': 1},
#  {'company': 'dong studio', 'count': 1},
#  {'company': 'donteco', 'count': 1},
#  {'company': 'donut games', 'count': 2},
#  {'company': 'donut publishing', 'count': 1},
#  {'company': 'doodle joy studio', 'count': 1},
#  {'company': 'doodle mobile ltd.', 'count': 4},
#  {'company': 'doomsday studio', 'count': 1},
#  {'company': 'door to apps', 'count': 1},
#  {'company': 'dopuz games', 'count': 1},
#  {'company': 'dot to dot s.r.o.', 'count': 1},
#  {'company': 'dotfinger games', 'count': 1},
#  {'company': 'dotgears', 'count': 1},
#  {'company': 'dotjoy', 'count': 1},
#  {'company': 'dotomchi games inc.', 'count': 1},
#  {'company': 'double down interactive llc', 'count': 1},
#  {'company': 'doublejump', 'count': 2},
#  {'company': 'doubletap software', 'count': 2},
#  {'company': 'doubleugames', 'count': 1},
#  {'company': 'dozing cat software', 'count': 1},
#  {'company': 'dps world', 'count': 1},
#  {'company': 'dr. panda', 'count': 7},
#  {'company': 'dragon fire z', 'count': 1},
#  {'company': 'dragon king creations', 'count': 1},
#  {'company': 'dragon smile company', 'count': 1},
#  {'company': 'dragonest game', 'count': 1},
#  {'company': 'dragosha', 'count': 1},
#  {'company': 'drawapp', 'count': 1},
#  {'company': 'dream hq', 'count': 1},
#  {'company': 'dreamgo', 'count': 1},
#  {'company': 'dreamotion inc.', 'count': 1},
#  {'company': 'dreamplay games', 'count': 1},
#  {'company': 'dreamsky', 'count': 5},
#  {'company': 'dreamy dingo', 'count': 2},
#  {'company': 'dress up games!', 'count': 1},
#  {'company': 'driant games', 'count': 1},
#  {'company': 'droid-developer', 'count': 2},
#  {'company': 'droidhen', 'count': 7},
#  {'company': 'droidveda llp', 'count': 1},
#  {'company': 'dry cactus limited', 'count': 1},
#  {'company': 'drygin studios', 'count': 1},
#  {'company': 'dsd 164', 'count': 1},
#  {'company': 'dual cat', 'count': 3},
#  {'company': 'duck duck moose, llc', 'count': 1},
#  {'company': 'dude perfect', 'count': 1},
#  {'company': 'dude soft', 'count': 1},
#  {'company': 'dunderbit', 'count': 1},
#  {'company': 'dunia games', 'count': 1},
#  {'company': 'duripuzzle', 'count': 1},
#  {'company': 'dustland design', 'count': 1},
#  {'company': 'dva apps', 'count': 1},
#  {'company': 'dvloper', 'count': 3},
#  {'company': 'dynamic games entretenimento ltda', 'count': 2},
#  {'company': 'dynamic games ltd.', 'count': 1},
#  {'company': 'dynamic games ltda', 'count': 1},
#  {'company': 'early morning studio', 'count': 1},
#  {'company': 'earthkwak games', 'count': 1},
#  {'company': 'east side games studio', 'count': 1},
#  {'company': 'easybrain', 'count': 5},
#  {'company': 'easygame7', 'count': 1},
#  {'company': 'easytech', 'count': 5},
#  {'company': 'ecapyc inc.', 'count': 2},
#  {'company': 'eco city games', 'count': 1},
#  {'company': 'eden games', 'count': 1},
#  {'company': 'educ8s.com', 'count': 3},
#  {'company': 'edunet indonesia', 'count': 1},
#  {'company': 'efez games', 'count': 1},
#  {'company': 'egames.com', 'count': 3},
#  {'company': 'egghead games llc', 'count': 2},
#  {'company': 'egproject', 'count': 1},
#  {'company': 'eivaagames', 'count': 2},
#  {'company': 'ejelta llc', 'count': 1},
#  {'company': 'ekkorr', 'count': 1},
#  {'company': 'electric turtle', 'count': 1},
#  {'company': 'electricpunch sandbox games', 'count': 1},
#  {'company': 'electronic arts', 'count': 17},
#  {'company': 'electrowolff games', 'count': 1},
#  {'company': 'elecube', 'count': 1},
#  {'company': 'elex', 'count': 4},
#  {'company': 'elex wireless', 'count': 2},
#  {'company': 'elpatrixf', 'count': 1},
#  {'company': 'ely anime games', 'count': 1},
#  {'company': 'elyland', 'count': 2},
#  {'company': 'ember entertainment', 'count': 2},
#  {'company': 'emily studio inc', 'count': 1},
#  {'company': 'emittercritter games', 'count': 1},
#  {'company': 'empire games', 'count': 1},
#  {'company': 'emubox jsc', 'count': 1},
#  {'company': 'enadun', 'count': 1},
#  {'company': 'end game', 'count': 1},
#  {'company': 'enfeel inc', 'count': 1},
#  {'company': 'english checkers', 'count': 1},
#  {'company': 'enixan', 'count': 1},
#  {'company': 'enjen games', 'count': 3},
#  {'company': 'enjoy your games', 'count': 1},
#  {'company': 'enjoysports', 'count': 2},
#  {'company': 'enp games', 'count': 1},
#  {'company': 'enrasoft', 'count': 1},
#  {'company': 'enteriosoft', 'count': 1},
#  {'company': 'entertainment one', 'count': 1},
#  {'company': 'epace games llc', 'count': 1},
#  {'company': 'eper apps', 'count': 1},
#  {'company': 'epic action llc', 'count': 1},
#  {'company': 'epic devs ood', 'count': 1},
#  {'company': 'epic stars', 'count': 1},
#  {'company': 'epic story interactive', 'count': 3},
#  {'company': 'epic war', 'count': 1},
#  {'company': 'epicoro games', 'count': 1},
#  {'company': 'epics digital collectibles, inc.', 'count': 1},
#  {'company': 'episode interactive', 'count': 1},
#  {'company': 'epsxe software s.l.', 'count': 1},
#  {'company': 'era of war', 'count': 1},
#  {'company': 'erahopes studio', 'count': 1},
#  {'company': 'erepublik labs', 'count': 2},
#  {'company': 'eric froemling', 'count': 1},
#  {'company': 'ernest szoka', 'count': 1},
#  {'company': 'erow.dev', 'count': 2},
#  {'company': 'errorsevendev', 'count': 3},
#  {'company': 'eryod soft', 'count': 4},
#  {'company': 'escapefunhk', 'count': 1},
#  {'company': 'esdroid', 'count': 1},
#  {'company': 'estoty entertainment llc', 'count': 1},
#  {'company': 'etermax', 'count': 4},
#  {'company': 'ethergaming', 'count': 1},
#  {'company': 'everbyte', 'count': 1},
#  {'company': 'everguild ltd.', 'count': 1},
#  {'company': 'everyday-apps', 'count': 1},
#  {'company': 'evgeniy kuklo', 'count': 1},
#  {'company': 'evgeny karavashkin', 'count': 2},
#  {'company': 'evil studios limited', 'count': 3},
#  {'company': 'evolution games gmbh', 'count': 2},
#  {'company': 'evolution of games', 'count': 2},
#  {'company': 'evolvegames', 'count': 1},
#  {'company': 'ewes academy', 'count': 1},
#  {'company': 'ewy go', 'count': 1},
#  {'company': 'exabytez', 'count': 1},
#  {'company': 'exits', 'count': 2},
#  {'company': 'exobyte', 'count': 1},
#  {'company': 'exophase', 'count': 1},
#  {'company': 'exploding kittens', 'count': 1},
#  {'company': 'exponenta', 'count': 1},
#  {'company': 'extereme games', 'count': 1},
#  {'company': 'extra pop', 'count': 1},
#  {'company': 'extreme developers', 'count': 1},
#  {'company': 'eyewind', 'count': 3},
#  {'company': 'eyougame(uss)', 'count': 2},
#  {'company': 'ezjoy', 'count': 6},
#  {'company': 'ezos', 'count': 1},
#  {'company': 'f-game studio', 'count': 1},
#  {'company': 'f0ris', 'count': 1},
#  {'company': 'fabricated reality', 'count': 1},
#  {'company': 'fabros', 'count': 1},
#  {'company': 'face plus', 'count': 1},
#  {'company': 'fair idle games by ren? m?ller', 'count': 1},
#  {'company': 'family kids games', 'count': 1},
#  {'company': 'famobi', 'count': 2},
#  {'company': 'fanatee, inc.', 'count': 2},
#  {'company': 'fantastic, yes', 'count': 1},
#  {'company': 'fantasy flight games', 'count': 2},
#  {'company': 'fantasy word games', 'count': 2},
#  {'company': 'farsight studios', 'count': 1},
#  {'company': 'fashion games for girls', 'count': 3},
#  {'company': 'fassor', 'count': 1},
#  {'company': 'fast emulator', 'count': 4},
#  {'company': 'fast free games', 'count': 3},
#  {'company': 'fast fun', 'count': 2},
#  {'company': 'fastone games', 'count': 3},
#  {'company': 'fat lion games: crafting & building adventure', 'count': 3},
#  {'company': 'fathermade', 'count': 1},
#  {'company': 'favary', 'count': 1},
#  {'company': 'fazbro', 'count': 2},
#  {'company': 'fbe games', 'count': 1},
#  {'company': 'fdg entertainment gmbh & co.kg', 'count': 9},
#  {'company': 'fearless sp. z o.o.', 'count': 1},
#  {'company': 'feelingtouch hk', 'count': 2},
#  {'company': 'feerik games', 'count': 1},
#  {'company': 'felix ungman', 'count': 1},
#  {'company': 'feral interactive', 'count': 1},
#  {'company': 'ferrero trading lux s.a.', 'count': 1},
#  {'company': 'fgames', 'count': 1},
#  {'company': 'fgl indie showcase', 'count': 1},
#  {'company': 'fi games', 'count': 1},
#  {'company': 'fictional factory inc', 'count': 1},
#  {'company': 'fighting arena', 'count': 1},
#  {'company': 'fil games', 'count': 1},
#  {'company': 'filimundus ab', 'count': 1},
#  {'company': 'fincon', 'count': 1},
#  {'company': 'finger legend inc.', 'count': 1},
#  {'company': 'fingersoft', 'count': 2},
#  {'company': 'fionxy games', 'count': 1},
#  {'company': 'fire game', 'count': 1},
#  {'company': 'fire stu', 'count': 1},
#  {'company': 'firecannon', 'count': 1},
#  {'company': 'firecracker software llc', 'count': 1},
#  {'company': 'firecraft studios', 'count': 1},
#  {'company': 'fireproof games', 'count': 2},
#  {'company': 'first touch games ltd.', 'count': 3},
#  {'company': 'five aces publishing ltd.', 'count': 2},
#  {'company': 'five dragons games', 'count': 1},
#  {'company': 'fiveamp', 'count': 1},
#  {'company': 'fizizi', 'count': 1},
#  {'company': 'flaregames', 'count': 6},
#  {'company': 'flashman games llc', 'count': 1},
#  {'company': 'flashpoint games, llc', 'count': 1},
#  {'company': 'flero games', 'count': 1},
#  {'company': 'flexsoft', 'count': 1},
#  {'company': 'flipline studios', 'count': 3},
#  {'company': 'flippfly llc', 'count': 1},
#  {'company': 'floppy', 'count': 1},
#  {'company': 'floralmong company', 'count': 2},
#  {'company': 'flow inc.', 'count': 1},
#  {'company': 'flowmotion entertainment - cooking and girl games', 'count': 1},
#  {'company': 'flowmotion entertainment: restaurant cooking games', 'count': 2},
#  {'company': 'flybird casual games', 'count': 1},
#  {'company': 'fm-studio', 'count': 1},
#  {'company': 'fng studios', 'count': 1},
#  {'company': 'fog.com', 'count': 1},
#  {'company': 'foggybus', 'count': 1},
#  {'company': 'foo foo', 'count': 1},
#  {'company': 'footy accums', 'count': 1},
#  {'company': 'foranj', 'count': 3},
#  {'company': 'forestking studio', 'count': 2},
#  {'company': 'forgegames', 'count': 1},
#  {'company': 'forqan smart tech', 'count': 4},
#  {'company': 'forsis studio', 'count': 2},
#  {'company': 'fort23 studio', 'count': 1},
#  {'company': 'fortis labs', 'count': 1},
#  {'company': 'four fats', 'count': 1},
#  {'company': 'four pixels games', 'count': 4},
#  {'company': 'fourdesire', 'count': 1},
#  {'company': 'foursaken media', 'count': 2},
#  {'company': 'fourthirtythree inc.', 'count': 3},
#  {'company': 'foxenon games', 'count': 1},
#  {'company': 'foxfun', 'count': 1},
#  {'company': 'foxglove studios ab', 'count': 1},
#  {'company': 'foxie ventures', 'count': 2},
#  {'company': 'foxnext games', 'count': 1},
#  {'company': 'foxygames', 'count': 1},
#  {'company': 'frag', 'count': 1},
#  {'company': 'francisco zurita', 'count': 1},
#  {'company': 'frasinapp', 'count': 1},
#  {'company': 'fredbear games ltd', 'count': 2},
#  {'company': 'free 3d crafting adventure games for boys & girls', 'count': 1},
#  {'company': 'free block puzzle games inc', 'count': 2},
#  {'company': 'free bubble shooter games', 'count': 1},
#  {'company': 'free classic puzzle game', 'count': 1},
#  {'company': 'free puzzle games, ltd.', 'count': 3},
#  {'company': 'free puzzles', 'count': 2},
#  {'company': 'freemanzlat', 'count': 1},
#  {'company': 'frenzoo', 'count': 1},
#  {'company': 'freshplanet', 'count': 2},
#  ...]

# %%
def IsCompanyExperienced(companiesList, company):
    companyGamesCount = next((listCompany["count"] for listCompany in companiesList if company == listCompany["company"]), None)
    if(companyGamesCount > 1):
        return True
    else:
        return False

# %%
df_merged["CompanyIsExperienced"] = df_merged.apply(lambda row: IsCompanyExperienced(companiesList, row["company"]),axis=1)

# %%
df_merged
# Out:
#                                  appname  \
# 0                     com.gamebasics.osm
# 1          com.fgol.HungrySharkEvolution
# 2                    com.zynga.livepoker
# 3     ee.dustland.android.dustlandsudoku
# 4             com.miniclip.eightballpool
# ...                                  ...
# 6037        com.berniiiiiiii.logomatchup
# 6038              com.gipnetix.berryking
# 6039                com.smilerlee.jewels
# 6040                   com.geargames.pfp
# 6041        com.daysofwonder.smallworld2
#
#                                               fancyname  \
# 0                           Online Soccer Manager (OSM)
# 1                                Hungry Shark Evolution
# 2     Zynga Poker ? Free Texas Holdem Online Card Games
# 3                                Sudoku - The Clean One
# 4                                           8 Ball Pool
# ...                                                 ...
# 6037                             "Memory" - Memory game
# 6038                                         Berry King
# 6039                                      Jewels Switch
# 6040                           Prehistoric Park Builder
# 6041                                     Small World 2
#
#                     company  purchases  ads  sharesinfo  shareslocation  \
# 0             gamebasics bv        1.0  1.0         0.0             0.0
# 1     ubisoft entertainment        1.0  1.0         0.0             0.0
# 2                     zynga        1.0  1.0         1.0             0.0
# 3           dustland design        1.0  1.0         0.0             0.0
# 4              miniclip.com        1.0  1.0         0.0             0.0
# ...                     ...        ...  ...         ...             ...
# 6037           berni mobile        NaN  NaN         NaN             NaN
# 6038          gameborn inc.        NaN  NaN         NaN             NaN
# 6039           words mobile        NaN  NaN         NaN             NaN
# 6040             gear games        NaN  NaN         NaN             NaN
# 6041                no info        NaN  NaN         NaN             NaN
#
#       unrestrictedinternet  usersinteract  game  ... top_price_item  price  \
# 0                      0.0            1.0     1  ...         109.99   free
# 1                      0.0            0.0     1  ...         109.99   free
# 2                      0.0            1.0     1  ...         350.00   free
# 3                      0.0            0.0     1  ...           2.99   free
# 4                      0.0            0.0     1  ...          99.99   free
# ...                    ...            ...   ...  ...            ...    ...
# 6037                   NaN            NaN     1  ...            NaN   free
# 6038                   NaN            NaN     1  ...            NaN   free
# 6039                   NaN            NaN     1  ...            NaN   free
# 6040                   NaN            NaN     1  ...            NaN   free
# 6041                   NaN            NaN     1  ...            NaN   free
#
#       paidapp rating numberreviews cleaned_numberReviews  \
# 0         0.0    4.5     1,656,120               1656120
# 1         0.0    4.5     6,495,234               6495234
# 2         0.0    4.5     2,315,552               2315552
# 3         0.0    4.6         6,639                  6639
# 4         0.0    4.5    17,053,699              17053699
# ...       ...    ...           ...                   ...
# 6037      0.0    4.1       84.91k+                 84910
# 6038      0.0    4.4       35.66k+                 35660
# 6039      0.0    4.7      728.57k+                728570
# 6040      0.0    4.6      316.56k+                316560
# 6041      0.0    4.3        5.66k+                  5660
#
#                                   App Id      Released  Last Updated  \
# 0                     com.gamebasics.osm   Oct 4, 2012  Nov 26, 2020
# 1          com.fgol.HungrySharkEvolution  Feb 22, 2013  Oct 27, 2020
# 2                    com.zynga.livepoker  Dec 21, 2010  Nov 04, 2020
# 3     ee.dustland.android.dustlandsudoku  Jul 20, 2017  Oct 29, 2020
# 4             com.miniclip.eightballpool  Jan 23, 2013  Nov 26, 2020
# ...                                  ...           ...           ...
# 6037        com.berniiiiiiii.logomatchup  Oct 26, 2012  Nov 28, 2020
# 6038              com.gipnetix.berryking  Jul 11, 2014  Aug 20, 2020
# 6039                com.smilerlee.jewels  Jun 13, 2013  Dec 26, 2019
# 6040                   com.geargames.pfp  Nov 28, 2012  Feb 17, 2014
# 6041        com.daysofwonder.smallworld2  Dec 11, 2013  Sep 01, 2020
#
#      CompanyIsExperienced
# 0                   False
# 1                    True
# 2                    True
# 3                   False
# 4                    True
# ...                   ...
# 6037                 True
# 6038                False
# 6039                 True
# 6040                 True
# 6041                False
#
# [6042 rows x 25 columns]
