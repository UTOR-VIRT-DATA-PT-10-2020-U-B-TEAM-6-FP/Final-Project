# %%
#Import file & resources

import pandas as pd

# %%
#Read file into df

df = pd.read_csv("Android apps.csv", low_memory=False)
df
# Out:
#                                  appname  \
# 0                com.netflix.mediaclient
# 1                      com.facebook.orca
# 2                     com.android.chrome
# 3                  com.google.android.gm
# 4                  com.grindrapp.android
# ...                                  ...
# 50212  mobi.easyorderapp.slagerijthyssen
# 50213             com.thalys.selfservice
# 50214                  com.freeme.camera
# 50215           com.thalys.missionreport
# 50216                 be.easix.easynurse
#
#                                       fancyname           category  \
# 0                                       Netflix      entertainment
# 1      Messenger ? Text and Video Chat for Free      communication
# 2                  Google Chrome: Fast & Secure      communication
# 3                                         Gmail      communication
# 4                             Grindr - Gay chat             social
# ...                                         ...                ...
# 50212                                 EasyOrder           shopping
# 50213                    e-PRESS&MORE by Thalys   news & magazines
# 50214                                    Dreame  books & reference
# 50215                    e-PRESS&MORE by Thalys   news & magazines
# 50216                           Easix Easynurse            medical
#
#              company                                          extrainfo  \
# 0      netflix, inc.  offers in-app purchases \ august 19, 2019 \ va...
# 1           facebook  offers in-app purchases \ august 20, 2019 \ va...
# 2         google llc  august 14, 2019 \ varies with device \ 5,000,0...
# 3         google llc  contains ads \ august 19, 2019 \ varies with d...
# 4         grindr llc  contains ads?offers in-app purchases \ august ...
# ...              ...                                                ...
# 50212      easyorder                shopping|            |            |
# 50213         thalys  june 28, 2019 \ 48m \ 1,000+ \ 3.1.1 \ 4.4 and...
# 50214   dreame media  offers in-app purchases \ october 16, 2019 \ 1...
# 50215         thalys  june 28, 2019 \ 48m \ 1,000+ \ 3.1.1 \ 4.4 and...
# 50216     easix bvba  july 18, 2019 \ 17m \ 1,000+ \ 1.1.7 \ 4.1 and...
#
#             source  purchases  ads  sharesinfo  shareslocation  ...  price  \
# 0      google play        1.0  0.0         0.0             0.0  ...   free
# 1      google play        1.0  0.0         0.0             1.0  ...   free
# 2      google play        0.0  0.0         0.0             0.0  ...   free
# 3      google play        0.0  1.0         0.0             0.0  ...   free
# 4      google play        1.0  1.0         0.0             0.0  ...   free
# ...            ...        ...  ...         ...             ...  ...    ...
# 50212      apkpure        NaN  NaN         NaN             NaN  ...    NaN
# 50213  google play        1.0  0.0         0.0             0.0  ...   free
# 50214  google play        1.0  0.0         0.0             0.0  ...   free
# 50215  google play        1.0  0.0         0.0             0.0  ...   free
# 50216  google play        0.0  0.0         0.0             0.0  ...   free
#
#        secondprice  paidapp rating  numberreviews  five  four three  two  one
# 0              NaN      0.0    4.5      7,287,852   100    13     4    2    9
# 1              NaN      0.0    4.2     69,050,158   100    15     9    4   15
# 2              NaN      0.0    4.3     17,065,648   100    18     9    4   10
# 3              NaN      0.0    4.4      6,272,191   100    16     7    3    9
# 4              NaN      0.0    3.5        365,432   100    21    17   12   53
# ...            ...      ...    ...            ...   ...   ...   ...  ...  ...
# 50212          NaN      NaN    NaN            NaN   NaN   NaN   NaN  NaN  NaN
# 50213          NaN      0.0    2.2             26    37     0    12   12  100
# 50214          NaN      0.0    4.5         103,31   100    24    12    2    2
# 50215          NaN      0.0    2.2             26    37     0    12   12  100
# 50216          NaN      0.0    2.8              5   100     0     0   50  100
#
# [50217 rows x 33 columns]

# %%
#Filter out non-game app data

df = df.loc[df['game']==1]
df
# Out:
#                                    appname  \
# 228                     com.gamebasics.osm
# 235          com.fgol.HungrySharkEvolution
# 246                    com.zynga.livepoker
# 247     ee.dustland.android.dustlandsudoku
# 254             com.miniclip.eightballpool
# ...                                    ...
# 50190       com.nianticlabs.hpwu.prod.ares
# 50192  com.daysofwonder.smallworld2_humble
# 50195                       com.lwarb.beta
# 50197       com.melesta.toydefense2flexion
# 50200           com.boombox.fapceolauncher
#
#                                                fancyname   category  \
# 228                          Online Soccer Manager (OSM)     sports
# 235                               Hungry Shark Evolution     arcade
# 246    Zynga Poker ? Free Texas Holdem Online Card Games     casino
# 247                               Sudoku - The Clean One     puzzle
# 254                                          8 Ball Pool     sports
# ...                                                  ...        ...
# 50190                       Harry Potter:  Wizards Unite  adventure
# 50192                                     Small World 2       board
# 50195                                        Brawl Stars     arcade
# 50197                          Toy Defense - TD Strategy   strategy
# 50200                                             FapCEO     puzzle
#
#                      company  \
# 228            gamebasics bv
# 235    ubisoft entertainment
# 246                    zynga
# 247          dustland design
# 254             miniclip.com
# ...                      ...
# 50190          niantic, inc.
# 50192                no info
# 50195  no company info given
# 50197          melsoft games
# 50200  no company info given
#
#                                                extrainfo       source  \
# 228    contains ads?offers in-app purchases \ august ...  google play
# 235    contains ads?offers in-app purchases \ august ...  google play
# 246    contains ads?offers in-app purchases \ august ...  google play
# 247    contains ads?offers in-app purchases \ march 1...  google play
# 254    contains ads?offers in-app purchases \ july 26...  google play
# ...                                                  ...          ...
# 50190  offers in-app purchases \ october 15, 2019 \ 7...  google play
# 50192  50+ thousand downloads   4.3 5.66k+ rating    ...   apksupport
# 50195  Internet Access network state Wake lock Change...      apkshub
# 50197  contains ads?offers in-app purchases \ june 12...  google play
# 50200  Internet Receive boot completed Access network...      apkshub
#
#        purchases  ads  sharesinfo  shareslocation  ...  price  secondprice  \
# 228          1.0  1.0         0.0             0.0  ...   free          NaN
# 235          1.0  1.0         0.0             0.0  ...   free          NaN
# 246          1.0  1.0         1.0             0.0  ...   free          NaN
# 247          1.0  1.0         0.0             0.0  ...   free          NaN
# 254          1.0  1.0         0.0             0.0  ...   free          NaN
# ...          ...  ...         ...             ...  ...    ...          ...
# 50190        1.0  0.0         0.0             0.0  ...   free          NaN
# 50192        NaN  NaN         NaN             NaN  ...   free          NaN
# 50195        1.0  NaN         NaN             0.0  ...    NaN          NaN
# 50197        1.0  1.0         0.0             0.0  ...   free          NaN
# 50200        0.0  NaN         NaN             0.0  ...    NaN          NaN
#
#        paidapp rating  numberreviews                five                four  \
# 228        0.0    4.5      1,656,120                 100                  14
# 235        0.0    4.5      6,495,234                 100                  13
# 246        0.0    4.5      2,315,552                 100                  15
# 247        0.0    4.6          6,639                 100                  19
# 254        0.0    4.5     17,053,699                 100                  13
# ...        ...    ...            ...                 ...                 ...
# 50190      0.0    3.9        268,773                 100                  40
# 50192      0.0    4.3         5.66k+  61.126.810.314.377  24.408.336.276.934
# 50195      NaN    NaN            NaN                 NaN                 NaN
# 50197      0.0    4.5         78,832                 100                  22
# 50200      NaN    NaN            NaN                 NaN                 NaN
#
#                     three                 two              one
# 228                     4                   2                7
# 235                     6                   2                7
# 246                     5                   1                8
# 247                     6                   2                3
# 254                     5                   2                8
# ...                   ...                 ...              ...
# 50190                  21                  12               24
# 50192  73.648.887.318.969  28.965.030.024.726  420.346.167.432
# 50195                 NaN                 NaN              NaN
# 50197                   6                   1                6
# 50200                 NaN                 NaN              NaN
#
# [11109 rows x 33 columns]

# %%
columns_keep = 'fancyname	company	purchases	ads	sharesinfo	shareslocation	unrestrictedinternet	usersinteract	game	age_rating	Parentalguidance	Downloads	categorygame	low_price_item	top_price_item	price	paidapp	rating	numberreviews'.split('\t')

# %%
#Keep features/columns

df = df[columns_keep]
df
# Out:
#                                                fancyname  \
# 228                          Online Soccer Manager (OSM)
# 235                               Hungry Shark Evolution
# 246    Zynga Poker ? Free Texas Holdem Online Card Games
# 247                               Sudoku - The Clean One
# 254                                          8 Ball Pool
# ...                                                  ...
# 50190                       Harry Potter:  Wizards Unite
# 50192                                     Small World 2
# 50195                                        Brawl Stars
# 50197                          Toy Defense - TD Strategy
# 50200                                             FapCEO
#
#                      company  purchases  ads  sharesinfo  shareslocation  \
# 228            gamebasics bv        1.0  1.0         0.0             0.0
# 235    ubisoft entertainment        1.0  1.0         0.0             0.0
# 246                    zynga        1.0  1.0         1.0             0.0
# 247          dustland design        1.0  1.0         0.0             0.0
# 254             miniclip.com        1.0  1.0         0.0             0.0
# ...                      ...        ...  ...         ...             ...
# 50190          niantic, inc.        1.0  0.0         0.0             0.0
# 50192                no info        NaN  NaN         NaN             NaN
# 50195  no company info given        1.0  NaN         NaN             0.0
# 50197          melsoft games        1.0  1.0         0.0             0.0
# 50200  no company info given        0.0  NaN         NaN             0.0
#
#        unrestrictedinternet  usersinteract  game age_rating  Parentalguidance  \
# 228                     0.0            1.0     1   everyone               0.0
# 235                     0.0            0.0     1        16+               0.0
# 246                     0.0            1.0     1        12+               0.0
# 247                     0.0            0.0     1   everyone               0.0
# 254                     0.0            0.0     1   everyone               0.0
# ...                     ...            ...   ...        ...               ...
# 50190                   0.0            0.0     1         7+               0.0
# 50192                   NaN            NaN     1    no info               0.0
# 50195                   NaN            0.0     1    no info               0.0
# 50197                   0.0            0.0     1         7+               0.0
# 50200                   NaN            0.0     1    no info               0.0
#
#          Downloads categorygame low_price_item top_price_item price  paidapp  \
# 228     10000000.0       sports           0.59         109.99  free      0.0
# 235    100000000.0       arcade           2.29         109.99  free      0.0
# 246     50000000.0       casino           0.59         350.00  free      0.0
# 247      1000000.0       puzzle           1.89           2.99  free      0.0
# 254    500000000.0       sports           0.79          99.99  free      0.0
# ...            ...          ...            ...            ...   ...      ...
# 50190    5000000.0    adventure           1.09         109.99  free      0.0
# 50192          NaN        board            NaN            NaN  free      0.0
# 50195          NaN       arcade            NaN            NaN   NaN      NaN
# 50197    1000000.0     strategy           0.99         109.99  free      0.0
# 50200          NaN       puzzle            NaN            NaN   NaN      NaN
#
#       rating numberreviews
# 228      4.5     1,656,120
# 235      4.5     6,495,234
# 246      4.5     2,315,552
# 247      4.6         6,639
# 254      4.5    17,053,699
# ...      ...           ...
# 50190    3.9       268,773
# 50192    4.3        5.66k+
# 50195    NaN           NaN
# 50197    4.5        78,832
# 50200    NaN           NaN
#
# [11109 rows x 19 columns]

# %%
# #Drop nan of numberreviews

df_notna = df[df['numberreviews'].notna()]
df_notna
# Out:
#                                                fancyname  \
# 228                          Online Soccer Manager (OSM)
# 235                               Hungry Shark Evolution
# 246    Zynga Poker ? Free Texas Holdem Online Card Games
# 247                               Sudoku - The Clean One
# 254                                          8 Ball Pool
# ...                                                  ...
# 50172                                       TETRIS Blitz
# 50188                                Worms 2: Armageddon
# 50190                       Harry Potter:  Wizards Unite
# 50192                                     Small World 2
# 50197                          Toy Defense - TD Strategy
#
#                        company  purchases  ads  sharesinfo  shareslocation  \
# 228              gamebasics bv        1.0  1.0         0.0             0.0
# 235      ubisoft entertainment        1.0  1.0         0.0             0.0
# 246                      zynga        1.0  1.0         1.0             0.0
# 247            dustland design        1.0  1.0         0.0             0.0
# 254               miniclip.com        1.0  1.0         0.0             0.0
# ...                        ...        ...  ...         ...             ...
# 50172          electronic arts        1.0  0.0         0.0             0.0
# 50188  team 17 digital limited        0.0  0.0         0.0             0.0
# 50190            niantic, inc.        1.0  0.0         0.0             0.0
# 50192                  no info        NaN  NaN         NaN             NaN
# 50197            melsoft games        1.0  1.0         0.0             0.0
#
#        unrestrictedinternet  usersinteract  game age_rating  Parentalguidance  \
# 228                     0.0            1.0     1   everyone               0.0
# 235                     0.0            0.0     1        16+               0.0
# 246                     0.0            1.0     1        12+               0.0
# 247                     0.0            0.0     1   everyone               0.0
# 254                     0.0            0.0     1   everyone               0.0
# ...                     ...            ...   ...        ...               ...
# 50172                   0.0            0.0     1   everyone               0.0
# 50188                   0.0            0.0     1         7+               0.0
# 50190                   0.0            0.0     1         7+               0.0
# 50192                   NaN            NaN     1    no info               0.0
# 50197                   0.0            0.0     1         7+               0.0
#
#          Downloads categorygame low_price_item top_price_item price  paidapp  \
# 228     10000000.0       sports           0.59         109.99  free      0.0
# 235    100000000.0       arcade           2.29         109.99  free      0.0
# 246     50000000.0       casino           0.59         350.00  free      0.0
# 247      1000000.0       puzzle           1.89           2.99  free      0.0
# 254    500000000.0       sports           0.79          99.99  free      0.0
# ...            ...          ...            ...            ...   ...      ...
# 50172   10000000.0       puzzle           1.09         109.99  free      0.0
# 50188    1000000.0     strategy            NaN            NaN  4.49      1.0
# 50190    5000000.0    adventure           1.09         109.99  free      0.0
# 50192          NaN        board            NaN            NaN  free      0.0
# 50197    1000000.0     strategy           0.99         109.99  free      0.0
#
#       rating numberreviews
# 228      4.5     1,656,120
# 235      4.5     6,495,234
# 246      4.5     2,315,552
# 247      4.6         6,639
# 254      4.5    17,053,699
# ...      ...           ...
# 50172    4.2       250,381
# 50188    3.9        61,603
# 50190    3.9       268,773
# 50192    4.3        5.66k+
# 50197    4.5        78,832
#
# [11013 rows x 19 columns]

# %%
test_text = "1 2 3 kplus"

re.search(regex_searchstring, test_text)
# Out:
# <re.Match object; span=(6, 7), match='k'>

# %%
import re 

regex_searchstring = '[a-zA-Z+-]'

# f = lambda row: row.apply(str).str.replace(".","").str.contains(keyword ,na=False, flags=re.IGNORECASE)

# df_filter = df_notna.numberreviews.str.contains('[a-zA-Z+-]')

# df_filter = df_notna.loc[df_notna['numberreviews'].apply(lambda x: if re.search(regex_searchstring, x)): True else: False]

df_filter = df_notna.loc[df_notna['numberreviews'].str.contains('[a-zA-Z+-]', regex=True)]

# df_filter = df_notna['numberreviews'].contains('[a-zA-Z+-]')
df_filter

# remove non numeric characters, ",;.''
# Out:
#                                               fancyname  \
# 860                                               Scale
# 866     Low Poly Art - Color by Number, Number Coloring
# 1484                                          Charades!
# 1969   Mine Passengers: Plane Simulator - Aircraft Game
# 2245                                           InstLife
# ...                                                 ...
# 50062                                    MONOPOLY Game
# 50065                   Space Towers Free (Unreleased)
# 50072                           BeOne VR Awareness Game
# 50109                                Ridiculous Fishing
# 50192                                    Small World 2
#
#                           company  purchases  ads  sharesinfo  shareslocation  \
# 860                good job games        1.0  1.0         0.0             0.0
# 866          piano music fun inc.        1.0  1.0         0.0             0.0
# 1484           fatchicken studios        1.0  1.0         0.0             0.0
# 1969            cheese hole games        1.0  1.0         0.0             0.0
# 2245         candywriter holdings        0.0  1.0         0.0             0.0
# ...                           ...        ...  ...         ...             ...
# 50062                     no info        NaN  NaN         NaN             NaN
# 50065                     no info        NaN  NaN         NaN             NaN
# 50072  beone development group bv        0.0  0.0         0.0             0.0
# 50109                    vlambeer        NaN  NaN         NaN             NaN
# 50192                     no info        NaN  NaN         NaN             NaN
#
#        unrestrictedinternet  usersinteract  game age_rating  Parentalguidance  \
# 860                     0.0            0.0     1   everyone               0.0
# 866                     0.0            0.0     1   everyone               0.0
# 1484                    0.0            0.0     1        12+               0.0
# 1969                    0.0            0.0     1         7+               0.0
# 2245                    0.0            0.0     1        16+               0.0
# ...                     ...            ...   ...        ...               ...
# 50062                   NaN            NaN     1    no info               0.0
# 50065                   NaN            NaN     1    no info               0.0
# 50072                   0.0            0.0     1   everyone               0.0
# 50109                   NaN            NaN     1        12+               0.0
# 50192                   NaN            NaN     1    no info               0.0
#
#         Downloads categorygame low_price_item top_price_item  \
# 860    10000000.0       puzzle           1.09          10.99
# 866     1000000.0       puzzle           4.89          14.99
# 1484    5000000.0         word           0.75           2.88
# 1969    1000000.0   simulation           0.99          49.99
# 2245    5000000.0   simulation            NaN            NaN
# ...           ...          ...            ...            ...
# 50062         NaN        board            NaN            NaN
# 50065        50.0         card            NaN            NaN
# 50072       100.0  educational            NaN            NaN
# 50109         NaN       arcade            NaN            NaN
# 50192         NaN        board            NaN            NaN
#
#                        price  paidapp                 rating  \
# 860    error during scraping      NaN  error during scraping
# 866    error during scraping      NaN  error during scraping
# 1484   error during scraping      NaN  error during scraping
# 1969   error during scraping      NaN  error during scraping
# 2245   error during scraping      NaN  error during scraping
# ...                      ...      ...                    ...
# 50062                   2.70      1.0                    3.6
# 50065      no info available      0.0        rating disabled
# 50072                   free      0.0        rating disabled
# 50109                   free      0.0                    4.5
# 50192                   free      0.0                    4.3
#
#                numberreviews
# 860    error during scraping
# 866    error during scraping
# 1484   error during scraping
# 1969   error during scraping
# 2245   error during scraping
# ...                      ...
# 50062                62.11k+
# 50065        rating disabled
# 50072        rating disabled
# 50109                13.91k+
# 50192                 5.66k+
#
# [2209 rows x 19 columns]

# %%
df_stringvalues = df_notna.filter
df_stringvalues

# %%
#Filter out rows where numberreviews is lower than threshold

# %%
#Drop columns as described

# %%
#Look for weird data rows e.g. 'errors during scraping' & look at distribution among ratings

# %%
#Create another column that rounds ratings up and look at distribution
